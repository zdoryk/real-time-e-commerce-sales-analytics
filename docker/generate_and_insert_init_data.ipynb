# %%
import pandas as pd
import os
from faker import Faker
import random
from sqlalchemy import create_engine

# Initialize Faker
fake = Faker()

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /home/danylozdoryk/Documents/real-time-e-commerce-sales-analytics/venv/lib/python3.11/site-packages (2.9.9)

# %% [markdown]
# ## Generate some fake data

# %% [markdown]
# ### Customers

# %%
num_customers = 100000

customers_data = []
for _ in range(num_customers):
    name = fake.name()
    address = fake.street_address()
    city = fake.city()
    postal_code = fake.postcode()
    country = fake.country()
    last_updated = fake.date_time_between(start_date='-1y', end_date='now')
    registration_date = fake.date_between(start_date='-5y', end_date='now')
    
    customers_data.append({
        'name': name,
        'address': address,
        'city': city,
        'postal_code': postal_code,
        'country': country,
        'last_updated': last_updated,
        'registration_date': registration_date
    })

# Create DataFrame
df_customers = pd.DataFrame(customers_data)

# %% [markdown]
# ## Suppliers

# %%
num_suppliers = 150 

suppliers_data = []
for _ in range(num_suppliers):
    name = fake.company()
    address = fake.street_address()
    city = fake.city()
    postal_code = fake.postcode()
    country = fake.country()
    phone_number = fake.phone_number()
    
    suppliers_data.append({
        'name': name,
        'address': address,
        'city': city,
        'postal_code': postal_code,
        'country': country,
        'phone_number': phone_number
    })

# Create DataFrame
df_suppliers = pd.DataFrame(suppliers_data)

# %% [markdown]
# ## Shippers

# %%
num_shippers = 20

shippers_data = []
for _ in range(num_shippers):
    name = fake.company()
    phone_number = fake.phone_number()
    
    shippers_data.append({
        'name': name,
        'phone_number': phone_number
    })

# Create DataFrame
df_shippers = pd.DataFrame(shippers_data)

# %% [markdown]
# ## Read all files as df

# %%
# Read the csv files
folder = 'raw_data'

file_names = os.listdir(folder)
df = pd.concat([pd.read_csv(folder + f'/{file_name}') for file_name in file_names if file_name.endswith('.csv')])
df
# Out:
#       category         subcategory  \
# 0        shoes           Mocassins
# 1        shoes           Mocassins
# 2        shoes           Mocassins
# 3        shoes  Sneakers & Baskets
# 4        shoes           Mocassins
# ...        ...                 ...
# 10203      men              Gilets
# 10204      men              Shirts
# 10205      men              Shirts
# 10206      men              Shirts
# 10207      men      Shorts de bain
#
#                                                     name  current_price  \
# 0      Chaussures décontractées antidérapantes en tis...          36.40
# 1      Chaussures en cuir à carreaux pour hommes de g...          46.36
# 2           Chaussures décontractées en cuir pour hommes          43.38
# 3         Baskets plates élastiques en tricot d'épissage          19.99
# 4      Hommes Cuir Épissage Soft Semelle Casual Chaus...          46.18
# ...                                                  ...            ...
# 10203  Gilets chauds d'extérieur élégants de couleur ...          54.99
# 10204                   Chemises décontractées à rayures          17.99
# 10205  Chemises à manches courtes à imprimé ours en p...          25.29
# 10206           Chemises imprimées ethniques pour hommes          23.09
# 10207  Plus Taille Deux Tortues De Mer Imprimé Deux P...          31.35
#
#        raw_price currency  discount  likes_count  is_new     brand  ...  \
# 0          72.80      USD        50          873   False       NaN  ...
# 1         106.49      USD        57          358   False       NaN  ...
# 2         119.98      USD        64         1511   False    Menico  ...
# 3          39.99      USD        50         1873   False       NaN  ...
# 4         119.98      USD        62         2738   False       NaN  ...
# ...          ...      ...       ...          ...     ...       ...  ...
# 10203      81.99      USD        33          176   False       NaN  ...
# 10204      33.99      USD        47           24   False       NaN  ...
# 10205      37.71      USD        33           84   False       NaN  ...
# 10206      33.94      USD        32           82   False       NaN  ...
# 10207      52.81      USD        41           38   False  ChArmkpR  ...
#
#       variation_0_color variation_1_color  \
# 0                 Black             Khaki
# 1                   Red              Blue
# 2                 Black             Khaki
# 3                 Green              Blue
# 4                  Bleu              Noir
# ...                 ...               ...
# 10203             rouge              Noir
# 10204             blanc              Noir
# 10205               #01               NaN
# 10206              Blue               NaN
# 10207              Blue               NaN
#
#                                    variation_0_thumbnail  \
# 0      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 1      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 2      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 4      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10204  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10205  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10206  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10207  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
#
#                                        variation_0_image  \
# 0      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10204  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10205  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10206  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10207  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                    variation_1_thumbnail  \
# 0      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 1      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 2      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 4      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10204  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10205                                                NaN
# 10206                                                NaN
# 10207                                                NaN
#
#                                        variation_1_image  \
# 0      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10204  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10205                                                NaN
# 10206                                                NaN
# 10207                                                NaN
#
#                                                image_url  \
# 0      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10204  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10205  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10206  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10207  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                                      url       id      model
# 0       https://fr.newchic.com/flats-3616/p-1687903.html  1687903  SKUF29428
# 1       https://fr.newchic.com/flats-3616/p-1533324.html  1533324  SKUC99128
# 2      https://fr.newchic.com/-menico-flats-3616/p-16...  1651734  SKUE68011
# 3      https://fr.newchic.com/sneakersandathletic-359...  1591892  SKUD85085
# 4       https://fr.newchic.com/flats-3616/p-1474682.html  1474682  SKUC15622
# ...                                                  ...      ...        ...
# 10203   https://fr.newchic.com/vests-4973/p-1214450.html  1214450  SKU788804
# 10204  https://fr.newchic.com/shirts-12209/p-1660726....  1660726  SKUE72114
# 10205  https://fr.newchic.com/shirts-12209/p-1661284....  1661284  SKUE74270
# 10206  https://fr.newchic.com/shirts-12209/p-1666391....  1666391  SKUE92625
# 10207  https://fr.newchic.com/charmkpr-board-shorts-6...  1669217  SKUE66551
#
# [74999 rows x 22 columns]

# %% [markdown]
# ## Create unique int id for categories table

# %%
category_to_id = {category: i + 1 for i, category in enumerate(df['category'].unique())}

df['category_id'] = df['category'].map(category_to_id)
df
# Out:
#       category         subcategory  \
# 0        shoes           Mocassins
# 1        shoes           Mocassins
# 2        shoes           Mocassins
# 3        shoes  Sneakers & Baskets
# 4        shoes           Mocassins
# ...        ...                 ...
# 10203      men              Gilets
# 10204      men              Shirts
# 10205      men              Shirts
# 10206      men              Shirts
# 10207      men      Shorts de bain
#
#                                                     name  current_price  \
# 0      Chaussures décontractées antidérapantes en tis...          36.40
# 1      Chaussures en cuir à carreaux pour hommes de g...          46.36
# 2           Chaussures décontractées en cuir pour hommes          43.38
# 3         Baskets plates élastiques en tricot d'épissage          19.99
# 4      Hommes Cuir Épissage Soft Semelle Casual Chaus...          46.18
# ...                                                  ...            ...
# 10203  Gilets chauds d'extérieur élégants de couleur ...          54.99
# 10204                   Chemises décontractées à rayures          17.99
# 10205  Chemises à manches courtes à imprimé ours en p...          25.29
# 10206           Chemises imprimées ethniques pour hommes          23.09
# 10207  Plus Taille Deux Tortues De Mer Imprimé Deux P...          31.35
#
#        raw_price currency  discount  likes_count  is_new     brand  ...  \
# 0          72.80      USD        50          873   False       NaN  ...
# 1         106.49      USD        57          358   False       NaN  ...
# 2         119.98      USD        64         1511   False    Menico  ...
# 3          39.99      USD        50         1873   False       NaN  ...
# 4         119.98      USD        62         2738   False       NaN  ...
# ...          ...      ...       ...          ...     ...       ...  ...
# 10203      81.99      USD        33          176   False       NaN  ...
# 10204      33.99      USD        47           24   False       NaN  ...
# 10205      37.71      USD        33           84   False       NaN  ...
# 10206      33.94      USD        32           82   False       NaN  ...
# 10207      52.81      USD        41           38   False  ChArmkpR  ...
#
#       variation_1_color                              variation_0_thumbnail  \
# 0                 Khaki  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 1                  Blue  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 2                 Khaki  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3                  Blue  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 4                  Noir  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# ...                 ...                                                ...
# 10203              Noir  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10204              Noir  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10205               NaN  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10206               NaN  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10207               NaN  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
#
#                                        variation_0_image  \
# 0      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10204  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10205  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10206  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10207  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                    variation_1_thumbnail  \
# 0      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 1      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 2      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 4      https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10204  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10205                                                NaN
# 10206                                                NaN
# 10207                                                NaN
#
#                                        variation_1_image  \
# 0      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10204  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10205                                                NaN
# 10206                                                NaN
# 10207                                                NaN
#
#                                                image_url  \
# 0      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4      https://imgaz1.chiccdn.com/thumb/view/oaupload...
# ...                                                  ...
# 10203  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10204  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10205  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10206  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10207  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                                      url       id      model  \
# 0       https://fr.newchic.com/flats-3616/p-1687903.html  1687903  SKUF29428
# 1       https://fr.newchic.com/flats-3616/p-1533324.html  1533324  SKUC99128
# 2      https://fr.newchic.com/-menico-flats-3616/p-16...  1651734  SKUE68011
# 3      https://fr.newchic.com/sneakersandathletic-359...  1591892  SKUD85085
# 4       https://fr.newchic.com/flats-3616/p-1474682.html  1474682  SKUC15622
# ...                                                  ...      ...        ...
# 10203   https://fr.newchic.com/vests-4973/p-1214450.html  1214450  SKU788804
# 10204  https://fr.newchic.com/shirts-12209/p-1660726....  1660726  SKUE72114
# 10205  https://fr.newchic.com/shirts-12209/p-1661284....  1661284  SKUE74270
# 10206  https://fr.newchic.com/shirts-12209/p-1666391....  1666391  SKUE92625
# 10207  https://fr.newchic.com/charmkpr-board-shorts-6...  1669217  SKUE66551
#
#       category_id
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 10203           9
# 10204           9
# 10205           9
# 10206           9
# 10207           9
#
# [74999 rows x 23 columns]

# %% [markdown]
# ## Create categories df

# %%
columns_to_select = ['category_id', 'category']
categories_df = df[columns_to_select].drop_duplicates(columns_to_select)
categories_df.rename(columns={'category_id': 'id', 'category': 'name'}, inplace=True)
categories_df['description'] = categories_df['name']
categories_df['image_url'] = 'https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.nationalgeographic.com%2Fanimals%2Fmammals%2Ffacts%2Fdomestic-cat&psig=AOvVaw3Uz0J9pnLJA9E0maBnFVr0&ust=1716227417597000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCKCe_72jmoYDFQAAAAAdAAAAABAE'
categories_df
# Out:
#    id         name  description  \
# 0   1        shoes        shoes
# 0   2      jewelry      jewelry
# 0   3  accessories  accessories
# 0   4         kids         kids
# 0   5       beauty       beauty
# 0   6        women        women
# 0   7        house        house
# 0   8         bags         bags
# 0   9          men          men
#
#                                            image_url
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...
# 0  https://www.google.com/url?sa=i&url=https%3A%2...

# %% [markdown]
# ## Create Products df

# %%
columns_to_select = ['name', 'category_id', 'subcategory','variation_0_color',  'current_price']
products_df = df[columns_to_select].drop_duplicates(columns_to_select)
products_df.rename(columns={'variation_0_color': 'description', 'current_price': 'price'}, inplace=True)

products_df['stock_qty'] = [random.randint(10, 1500) for _ in range(len(products_df))]
products_df['supplier_id'] = [random.randint(1, 150) for _ in range(len(products_df))]
products_df
# Out:
#                                                     name  category_id  \
# 0      Chaussures décontractées antidérapantes en tis...            1
# 1      Chaussures en cuir à carreaux pour hommes de g...            1
# 2           Chaussures décontractées en cuir pour hommes            1
# 3         Baskets plates élastiques en tricot d'épissage            1
# 4      Hommes Cuir Épissage Soft Semelle Casual Chaus...            1
# ...                                                  ...          ...
# 10203  Gilets chauds d'extérieur élégants de couleur ...            9
# 10204                   Chemises décontractées à rayures            9
# 10205  Chemises à manches courtes à imprimé ours en p...            9
# 10206           Chemises imprimées ethniques pour hommes            9
# 10207  Plus Taille Deux Tortues De Mer Imprimé Deux P...            9
#
#               subcategory description  price  stock_qty  supplier_id
# 0               Mocassins       Black  36.40        903           42
# 1               Mocassins         Red  46.36        352           94
# 2               Mocassins       Black  43.38       1226          115
# 3      Sneakers & Baskets       Green  19.99       1114            4
# 4               Mocassins        Bleu  46.18        343           51
# ...                   ...         ...    ...        ...          ...
# 10203              Gilets       rouge  54.99        792          126
# 10204              Shirts       blanc  17.99         21           33
# 10205              Shirts         #01  25.29       1012          109
# 10206              Shirts        Blue  23.09        715           87
# 10207      Shorts de bain        Blue  31.35        569           64
#
# [74260 rows x 7 columns]

# %% [markdown]
# ## Insert data

# %%
# Establish a connection to the PostgreSQL database
engine = create_engine('postgresql://postgres:1234@localhost:5432/postgres')

# Write the DataFrame to the database
categories_df.to_sql(name='categories', con=engine, if_exists='truncate', index=False)
df_customers.to_sql(name='customers', con=engine, if_exists='append', index=False)
df_shippers.to_sql(name='shippers', con=engine, if_exists='append', index=False)
df_suppliers.to_sql(name='suppliers', con=engine, if_exists='append', index=False)
products_df.to_sql(name='products', con=engine, if_exists='append', index=False)

# Close the connection
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 5
#       2 engine = create_engine('postgresql://postgres:1234@localhost:5432/postgres')
#       4 # Write the DataFrame to the database
# ----> 5 categories_df.to_sql(name='categories', con=engine, if_exists='truncate', index=False)
#       6 # df_customers.to_sql(name='customers', con=engine, if_exists='append', index=False)
#       7 # df_shippers.to_sql(name='shippers', con=engine, if_exists='append', index=False)
#       8 # df_suppliers.to_sql(name='suppliers', con=engine, if_exists='append', index=False)
#       9 # products_df.to_sql(name='products', con=engine, if_exists='append', index=False)
#      10
#      11 # Close the connection
#      12 engine.dispose()
#
# File ~/Documents/real-time-e-commerce-sales-analytics/venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Documents/real-time-e-commerce-sales-analytics/venv/lib/python3.11/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~/Documents/real-time-e-commerce-sales-analytics/venv/lib/python3.11/site-packages/pandas/io/sql.py:832, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     760 """
#     761 Write records stored in a DataFrame to a SQL database.
#     762
#    (...)
#     829 `SQLAlchemy <https://docs.sqlalchemy.org/en/14/core/connections.html#sqlalchemy.engine.BaseCursorResult.rowcount>`__
#     830 """  # noqa: E501
#     831 if if_exists not in ("fail", "replace", "append"):
# --> 832     raise ValueError(f"'{if_exists}' is not valid for if_exists")
#     834 if isinstance(frame, Series):
#     835     frame = frame.to_frame()
#
# ValueError: 'truncate' is not valid for if_exists
